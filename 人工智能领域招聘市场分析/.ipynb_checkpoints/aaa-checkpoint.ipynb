# %%
import pandas as pd
df = pd.read_csv('51job/人工智能.csv', engine='python', encoding='utf8')
print(df.shape)
print(len(df.columns), df.columns)
df.head()
# Out:
# (14383, 5)
# 5 Index(['company', 'jobRequirement', 'salary', 'tags', 'title'], dtype='object')
#             company                                     jobRequirement  \
# 0    北京捷通华声科技股份有限公司      职位描述：,      1.负责智能机器人知识库的建设，保证机器人智能问答的准确率；...
# 1               NaN                                                NaN
# 2  寰宇优才教育科技（北京）有限公司  【岗位方向】：,1、 Java+大数据软件开发工程师实习生,2、 人工智能+Python开发...
# 3     广州市润东信息科技有限公司  1. 研究机器学习、深度学习等领域的前沿技术并结合业务场景解决实际问题；,2. 通过对数据的...
# 4   江苏厚学网信息技术股份有限公司  岗位职责:,1. 开发软电话模块，完成与终端呼叫设备的对接；,2. 负责模块的需求分析，代码...
#
#      salary                                          tags               title
# 0  0.7-1万/月       北京  |  无工作经验  |  本科  |  招3人  |  08-14发布           人工智能训练工程师
# 1       NaN                                           NaN                 NaN
# 2    6-8千/月         北京-朝阳区  |  无工作经验  |  招16人  |  08-14发布      Java+人工智能实习工程师
# 3  1.5-2万/月  广州-番禺区  |  3-4年经验  |  本科  |  招1人  |  08-14发布             人工智能工程师
# 4  10-20万/年  南京-秦淮区  |  3-4年经验  |  大专  |  招4人  |  08-14发布  C++高级开发工程师(人工智能方向)

# %%
#数据处理，删除空行
print('删除空行前共有%d行' %len(df))
df = df.dropna(how='all')
print('删除空行后共有%d行' %len(df))
# Out:
# 删除空行前共有14383行
# 删除空行后共有14304行

# %%
#使用jieba库进行中文分词
import pandas as pd
import jieba
import re

df = pd.read_csv('51job/人工智能.csv', engine='python', encoding='utf8')
alltext=df.jobRequirement.dropna().map(str.lower)
text=''
for line in alltext:
    line = line.strip()
    line = re.sub(r"[0-9\s+\.\!\/_,$%^*()?;；:-【】+\"\']+|[-+——！，;:：。？、~@#￥%……&*（）]+", " ", line)
    text+=' '+line
top200_keyword = pd.value_counts(list(jieba.cut(text))).iloc[:200]
print(top200_keyword.iloc[:50])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\tarena\AppData\Local\Temp\jieba.cache
# Loading model cost 0.707 seconds.
# Prefix dict has been built succesfully.
#         902474
# 的       133663
# 和        41381
# 有        30979
# 等        30421
# 工作       23402
# 能力       22512
# 及        20737
# 你        20113
# 公司       19500
# 客户       18878
# 与        17561
# 经验       17416
# 产品       14727
# 相关       14023
# 我们       13980
# 在        13812
# 团队       13667
# 开发       13664
# 人工智能     13262
# 学习       13107
# 负责       13067
# 技术       12778
# 优先       12548
# 培训       11592
# 年        11243
# 熟悉       11078
# 我        11024
# 沟通       10509
# 项目       10457
# 行业       10347
# 青客       10317
# 为         9971
# 要求        9719
# 销售        9521
# 是         9368
# 数据        9119
# 对         9026
# 元         8939
# 服务        8868
# 提供        8694
# 并         8582
# 具有        8480
# 或         8423
# 良好        7943
# 以上        7792
# 不         7720
# 专业        7635
# 业务        7596
# 大         7535
# dtype: int64

# %%
#根据自己设定的关键字绘制词云图
from pyecharts import WordCloud
import pandas as pd

def drawWordCloud(allText):
    with open('keyword.txt', encoding='utf-8') as file:
        keyword_list = [k.strip() for k in file.readlines()]
    count_list = []
    for keyword in keyword_list:
        count_list.append(allText.count(keyword))
    top20_keyword = pd.Series(count_list, index=keyword_list).sort_values(ascending=False).iloc[:20]
    print(top20_keyword)
    wordcloud = WordCloud(width=900, height=600)
    wordcloud.add('', keyword_list, count_list, word_size_range=[20,100])
    return wordcloud

df = pd.read_csv('51job/人工智能.csv', engine='python', encoding='utf8')
allText = ' '.join(df.jobRequirement.dropna().map(str.lower))
print('字符串allText变量的长度:',len(allText))
drawWordCloud(allText)
# Out:
# 字符串allText变量的长度: 7164775
# 人工智能      13262
# 培训        12148
# 算法         6389
# 大数据        5486
# 科技         5249
# 计算机        5145
# 互联网        4954
# 上海         3597
# 北京         3139
# 机器学习       2681
# 机器人        2535
# 杭州         2308
# 责任心        2234
# 深度学习       2210
# java       2172
# python     2072
# 数据库        1681
# 数据分析       1596
# 吃苦         1519
# 软件开发       1443
# dtype: int64
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="56df888c478545c3a0c39f22edc285f4" style="width:900px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_56df888c478545c3a0c39f22edc285f4 = echarts.init(document.getElementById('56df888c478545c3a0c39f22edc285f4'), 'light', {renderer: 'canvas'});
#
# var option_56df888c478545c3a0c39f22edc285f4 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 805985,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\ufeff\u4ea7\u54c1",
#                     "value": 0,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,43,21)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b97\u6cd5",
#                     "value": 6389,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,91,111)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e92\u8054\u7f51",
#                     "value": 4954,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,98,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u6280",
#                     "value": 5249,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(123,142,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u5de5\u667a\u80fd",
#                     "value": 13262,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(61,104,51)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u5668\u5b66\u4e60",
#                     "value": 2681,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(60,102,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6df1\u5ea6\u5b66\u4e60",
#                     "value": 2210,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(90,131,65)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u8bc6\u522b",
#                     "value": 359,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,69,6)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4eba\u8138\u8bc6\u522b",
#                     "value": 351,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,19,70)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56fe\u50cf\u5904\u7406",
#                     "value": 1082,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(133,75,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9879\u76ee\u7ba1\u7406",
#                     "value": 985,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,115,78)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u81ea\u7136\u8bed\u8a00",
#                     "value": 830,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(7,119,99)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79ef\u6781\u4e3b\u52a8",
#                     "value": 625,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,83,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6a21\u5f0f\u8bc6\u522b",
#                     "value": 576,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,26,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 3139,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,22,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": 2308,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,11,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 3597,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,132,116)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": 820,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,94,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "nlp",
#                     "value": 370,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,96,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u65e0\u4eba\u9a7e\u9a76",
#                     "value": 85,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(3,102,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8bed\u97f3\u8bc6\u522b",
#                     "value": 478,
#                     "te

# %%
# 全国城市的岗位需求量分析
workPlace = df.tags.dropna().map(lambda x:x.split('|')[0].strip())
city = workPlace.map(lambda x:x.split('-')[0])
region = workPlace.map(lambda x:x.split('-')[1] if len(x.split('-'))>1 else '')
city_jobCount = city.value_counts(ascending=False).iloc[:10]
city_jobCount
# Out:
# 上海     3027
# 北京     1835
# 深圳     1647
# 广州     1259
# 杭州     1158
# 成都      553
# 武汉      545
# 南京      448
# 苏州      406
# 石家庄     290
# Name: tags, dtype: int64

# %%
#画出柱状图，可视化
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.figure(figsize=(10,6))
city_jobCount.plot(kind='bar',width=0.8)
plt.xlabel('City',fontsize=16)
plt.ylabel('Num',fontsize=16)
# plt.bar(city_jobCount.index,city_jobCount.values)
plt.show()
#从图中可看出，人工智能相关职位上海需求量最高，之后分别是北京、深圳、广州、杭州、成都等城市。

# %%
#统计上海地区工作岗位的分布
shanghai_region = region[city=='上海']
region_count_series = shanghai_region.value_counts().drop([''])
region_count_series
# Out:
# 浦东新区    579
# 徐汇区     347
# 嘉定区     266
# 杨浦区     224
# 静安区     162
# 闵行区     148
# 宝山区     131
# 普陀区     106
# 黄浦区     103
# 松江区      99
# 奉贤区      77
# 长宁区      72
# 虹口区      63
# 青浦区      54
# 金山区      28
# Name: tags, dtype: int64

# %%
#数据可视化，热力图
from pyecharts import Map
map1 = Map('上海各区岗位需求量', width=900, height=800)
attr = region_count_series.index
value = region_count_series.values/region_count_series.max() * 100
map1.add('', attr, value, maptype='上海', is_visualmap=True, is_label_show=True)
map1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'shanghai': '/nbextensions/echarts-china-cities-js/shanghai'
#         }
#     });
# </script>
#     <div id="932d082c536e433396bd7db863b0591f" style="width:900px;height:800px;"></div>
#
#
# <script>
#     require(['echarts', 'shanghai'], function(echarts) {
#
# var myChart_932d082c536e433396bd7db863b0591f = echarts.init(document.getElementById('932d082c536e433396bd7db863b0591f'), 'light', {renderer: 'canvas'});
#
# var option_932d082c536e433396bd7db863b0591f = {
#     "title": [
#         {
#             "text": "\u4e0a\u6d77\u5404\u533a\u5c97\u4f4d\u9700\u6c42\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 574154,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u4e0a\u6d77",
#             "data": [
#                 {
#                     "name": "\u6d66\u4e1c\u65b0\u533a",
#                     "value": 100.0
#                 },
#                 {
#                     "name": "\u5f90\u6c47\u533a",
#                     "value": 59.930915371329874
#                 },
#                 {
#                     "name": "\u5609\u5b9a\u533a",
#                     "value": 45.9412780656304
#                 },
#                 {
#                     "name": "\u6768\u6d66\u533a",
#                     "value": 38.68739205526771
#                 },
#                 {
#                     "name": "\u9759\u5b89\u533a",
#                     "value": 27.979274611398964
#                 },
#                 {
#                     "name": "\u95f5\u884c\u533a",
#                     "value": 25.561312607944732
#                 },
#                 {
#                     "name": "\u5b9d\u5c71\u533a",
#                     "value": 22.625215889464595
#                 },
#                 {
#                     "name": "\u666e\u9640\u533a",
#                     "value": 18.307426597582037
#                 },
#                 {
#                     "name": "\u9ec4\u6d66\u533a",
#                     "value": 17.78929188255613
#                 },
#                 {
#                     "name": "\u677e\u6c5f\u533a",
#                     "value": 17.098445595854923
#                 },
#                 {
#                     "name": "\u5949\u8d24\u533a",
#                     "value": 13.298791018998275
#                 },
#                 {
#                     "name": "\u957f\u5b81\u533a",
#                     "value": 12.435233160621761
#                 },
#                 {
#                     "name": "\u8679\u53e3\u533a",
#                     "value": 10.880829015544041
#                 },
#                 {
#                     "name": "\u9752\u6d66\u533a",
#                     "value": 9.32642487046632
#                 },
#                 {
#                     "name": "\u91d1\u5c71\u533a",
#                     "value": 4.8359240069084635
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {},
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_932d082c536e433396bd7db863b0591f.setOption(option_932d082c536e433396bd7db863b0591f);
#
#     });
# </script>

# %%
#数据可视化，饼图
value2 = region_count_series.values/region_count_series.max() * 100
plt.pie(value2,labels=attr,autopct = '%3.1f%%')
plt.axis('equal')
plt.title('上海各区需求量占比')
plt.show()
#从图中可以看出，上海市的人工智能相关职位需求量浦东新区最高，之后分别是徐汇区、嘉定区、杨浦区、静安区等

# %%
#统计杭州地区工作岗位的分布
shanghai_region = region[city=='杭州']
region_count_series = shanghai_region.value_counts().drop([''])
region_count_series
# Out:
# 余杭区    185
# 滨江区    179
# 西湖区    149
# 江干区     60
# 拱墅区     55
# 萧山区     34
# 临安区     12
# 下城区      7
# 上城区      5
# 建德市      2
# 富阳区      1
# Name: tags, dtype: int64

# %%
#数据可视化，热力图
from pyecharts import Map
map1 = Map('杭州各区岗位需求量', width=900, height=800)
attr = region_count_series.index
value = region_count_series.values/region_count_series.max() * 100
map1.add('', attr, value, maptype='杭州', is_visualmap=True, is_label_show=True)
map1
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'hang2_zhou1': '/nbextensions/echarts-china-cities-js/zhe4_jiang1_hang2_zhou1'
#         }
#     });
# </script>
#     <div id="10dcfb2d0d2b43ec828b5d9a12ecd20f" style="width:900px;height:800px;"></div>
#
#
# <script>
#     require(['echarts', 'hang2_zhou1'], function(echarts) {
#
# var myChart_10dcfb2d0d2b43ec828b5d9a12ecd20f = echarts.init(document.getElementById('10dcfb2d0d2b43ec828b5d9a12ecd20f'), 'light', {renderer: 'canvas'});
#
# var option_10dcfb2d0d2b43ec828b5d9a12ecd20f = {
#     "title": [
#         {
#             "text": "\u676d\u5dde\u5404\u533a\u5c97\u4f4d\u9700\u6c42\u91cf",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7602793,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "\u676d\u5dde",
#             "data": [
#                 {
#                     "name": "\u4f59\u676d\u533a",
#                     "value": 100.0
#                 },
#                 {
#                     "name": "\u6ee8\u6c5f\u533a",
#                     "value": 96.75675675675676
#                 },
#                 {
#                     "name": "\u897f\u6e56\u533a",
#                     "value": 80.54054054054053
#                 },
#                 {
#                     "name": "\u6c5f\u5e72\u533a",
#                     "value": 32.432432432432435
#                 },
#                 {
#                     "name": "\u62f1\u5885\u533a",
#                     "value": 29.72972972972973
#                 },
#                 {
#                     "name": "\u8427\u5c71\u533a",
#                     "value": 18.37837837837838
#                 },
#                 {
#                     "name": "\u4e34\u5b89\u533a",
#                     "value": 6.486486486486487
#                 },
#                 {
#                     "name": "\u4e0b\u57ce\u533a",
#                     "value": 3.783783783783784
#                 },
#                 {
#                     "name": "\u4e0a\u57ce\u533a",
#                     "value": 2.7027027027027026
#                 },
#                 {
#                     "name": "\u5efa\u5fb7\u5e02",
#                     "value": 1.0810810810810811
#                 },
#                 {
#                     "name": "\u5bcc\u9633\u533a",
#                     "value": 0.5405405405405406
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {},
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_10dcfb2d0d2b43ec828b5d9a12ecd20f.setOption(option_10dcfb2d0d2b43ec828b5d9a12ecd20f);
#
#     });
# </script>

# %%
#数据可视化，饼图
value2 = region_count_series.values/region_count_series.max() * 100
plt.pie(value2,labels=attr,autopct = '%3.1f%%')
plt.axis('equal')
plt.title('杭州各区需求量占比')
plt.show()
#从图中可以看出，杭州市的人工智能相关职位需求量余杭区最高，之后分别是滨江区、西湖区，江干区等

# %%
#学历要求分析(51job)
df = pd.read_csv('51job/51job.csv',engine='python', encoding='utf8')
print(df.head())
print(df.columns)
print(df.shape)
#数据处理，删除空行
print('删除空行前共有%d行' %len(df))
df = df.dropna(how='all')
print('删除空行后共有%d行' %len(df))
# Out:
#    Unnamed: 0               title           company    min_salary  ave_salary  \
# 0           0           人工智能训练工程师    北京捷通华声科技股份有限公司   7000.000000      8500.0
# 1           2      Java+人工智能实习工程师  寰宇优才教育科技（北京）有限公司   6000.000000      7000.0
# 2           3             人工智能工程师     广州市润东信息科技有限公司  15000.000000     17500.0
# 3           4  C++高级开发工程师(人工智能方向)   江苏厚学网信息技术股份有限公司   8333.333333     12500.0
# 4           5        零基础人工智能开发实习生     郑州汇之众网络科技有限公司   6000.000000      7000.0
#
#      max_salary workspace experienceRequirement educationRequirement  \
# 0  10000.000000      北京                 无工作经验                   本科
# 1   8000.000000        北京               无工作经验                    无要求
# 2  20000.000000        广州              3-4年经验                   本科
# 3  16666.666667        南京              3-4年经验                   大专
# 4   8000.000000      郑州                 无工作经验                   本科
#
#    recruits                                     jobRequirement publishTime
# 0     招3人        职位描述：,      1.负责智能机器人知识库的建设，保证机器人智能问答的准确率；...     08-14发布
# 1    招16人    【岗位方向】：,1、 Java+大数据软件开发工程师实习生,2、 人工智能+Python开发...     08-14发布
# 2     招1人    1. 研究机器学习、深度学习等领域的前沿技术并结合业务场景解决实际问题；,2. 通过对数据的...     08-14发布
# 3     招4人    岗位职责:,1. 开发软电话模块，完成与终端呼叫设备的对接；,2. 负责模块的需求分析，代码...     08-14发布
# 4    招若干人    1、热爱编程事业，热衷IT行业；, 2、本科以上学历，计算机及理工类专业优先；, 3、认真遵...     08-14发布
# Index(['Unnamed: 0', 'title', 'company', 'min_salary', 'ave_salary',
#        'max_salary', 'workspace', 'experienceRequirement',
#        'educationRequirement', 'recruits', 'jobRequirement', 'publishTime'],
#       dtype='object')
# (11741, 12)
# 删除空行前共有11741行
# 删除空行后共有11741行

# %%
# 学历要求分析(51job)
er=df.educationRequirement
value=[i.strip() for i in er.values]
edu=pd.Series(value,index=er.index)
print(edu.shape)
# print(edu)
count_edu = edu.value_counts(ascending=False)
count_edu = count_edu[count_edu/count_edu.sum()>0.01]
plt.pie(count_edu.values,labels=count_edu.index,autopct = '%3.1f%%')
plt.axis('equal')
plt.title('学历要求占比(51job)')
plt.show()
# Out:
# (11741,)

# %%
#学历要求分析(拉勾网)
keyword_list = ['NLP', '机器学习', '人工智能', '人脸识别', '深度学习',
               '算法研究员', '图像识别', '无人驾驶', '语音识别']
fileName_list = ['拉勾/'+k+'.csv' for k in keyword_list]
df_list = [pd.read_csv(open(fileName, encoding='utf8')) for fileName in fileName_list]
df_all = pd.concat(df_list)
df_all = df_all.reset_index(drop=True)
print(df_all.shape)
# print(df_all)
#数据处理，删除空行
# print('删除空行前共有%d行' %len(df_all))
df_all = df_all.dropna(how='all')
# print('删除空行后共有%d行' %len(df_all))
edu=pd.Series(df_all['学历要求'].str.strip('及以上'))
count_edu = edu.value_counts(ascending=False)
count_edu = count_edu[count_edu/count_edu.sum()>0.01]
print(count_edu)
plt.pie(count_edu.values,labels=count_edu.index,autopct = '%3.1f%%')
plt.axis('equal')
plt.title('学历要求占比(拉勾)')
plt.show()
#根据实际情况，拉勾网比51job的数据更靠谱一些
# Out:
# (4733, 13)
# 本科      2901
# 硕士      1219
# 大专       318
# 学历不限     207
# 博士        74
# Name: 学历要求, dtype: int64

# %%
#薪资对比
import pandas as pd 

keyword_list = ['NLP', '机器学习', '人工智能', '人脸识别', '深度学习',
               '算法研究员', '图像识别', '无人驾驶', '语音识别']
fileName_list = ['拉勾/'+k+'.csv' for k in keyword_list]
df_list = [pd.read_csv(open(fileName, encoding='utf8')) for fileName in fileName_list]
salary_list = [df['薪资区间'].dropna() for df in df_list]  
salary_list2 = [salary[salary.str.contains('-')] for salary in salary_list]
salary_list3 = [salary.map(lambda x:x.lower().replace('k','000')) for salary in salary_list2]
# print(salary_list3)
for salary in salary_list3:
    print(len(salary))
# Out:
# 445
# 897
# 448
# 450
# 447
# 448
# 899
# 235
# 445

# %%
#获取较低值、较高值、平均值
import numpy as np
salaryLow_list = [salary.map(lambda x:int(x.split('-')[0])).quantile(0.5) for salary in salary_list3]
salaryHigh_list = [salary.map(lambda x:int(x.split('-')[1])).quantile(0.5) for salary in salary_list3]
salaryAvg_list = [salary.map(lambda x:np.average([int(k) for k in x.split('-')])).quantile(0.5) for salary in salary_list3]
print(salaryLow_list)
print(salaryHigh_list)
print(salaryAvg_list)
# Out:
# [20000.0, 15000.0, 15000.0, 15000.0, 20000.0, 20000.0, 12000.0, 15000.0, 18000.0]
# [40000.0, 30000.0, 30000.0, 30000.0, 35000.0, 35000.0, 20000.0, 30000.0, 30000.0]
# [30000.0, 22500.0, 22500.0, 22500.0, 27500.0, 27500.0, 17500.0, 22500.0, 24000.0]

# %%
#可视化
plt.figure(figsize=(18,8))
min_x = range(1, 42, 5)
max_x = range(2, 43, 5)
avg_x = range(3, 44, 5)
plt.bar(min_x, salaryLow_list, color='limegreen', label='薪酬较低值')
plt.bar(max_x, salaryHigh_list, color='orangered', label='薪酬较高值')
plt.bar(avg_x, salaryAvg_list, color='dodgerblue', label='薪酬平均值')
plt.xticks(range(2, 45, 5), keyword_list, fontsize=14)
plt.xlabel('Position', fontsize=16)
plt.ylabel('Salary', fontsize=16)
plt.title('人工智能相关岗位薪酬对比',fontsize=20)
plt.legend()
plt.show()
